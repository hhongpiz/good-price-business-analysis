# %%
# 패키지 임포트
import selenium
from selenium import webdriver
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import time
from tqdm import tqdm_notebook

# %%
res_table = pd.read_csv("./동작구 표본.csv", encoding='CP949')
res_table
# Out:
#     상세영업상태명        전화번호  소재지면적  소재지우편번호                                  지번주소  \
# 0        영업         NaN  69.34   156800          서울특별시 동작구 노량진동 57-1 메가스터디타워
# 1        영업         NaN  26.00   156871                 서울특별시 동작구 상도1동 804-1
# 2        영업         NaN  64.74   156849  서울특별시 동작구 신대방동 395-70번지 전문건설회관 지하1층
# 3        영업         NaN  30.00   156843                  서울특별시 동작구 상도동 355-8
# 4        영업  02 8156555  16.01   156804                서울특별시 동작구 노량진동 261-10
# ..      ...         ...    ...      ...                                   ...
# 331      영업  02 5889255  19.42   156879        서울특별시 동작구 사당동 206-12번지 (지상1층)
# 332      영업     8133838  23.20   156843                 서울특별시 동작구 상도동 250-16
# 333      영업         NaN  57.81   156030                서울특별시 동작구 상도동 507-3번지
# 334      영업    28240216  29.50   156030                    서울특별시 동작구 상도동 535
# 335      영업  7078080684  14.50   156838                 서울특별시 동작구 상도동 181-15
#
#                                                도로명주소  도로명우편번호            사업장명  \
# 0        서울특별시 동작구 노량진로 140 메가스터디타워 상가동층 115호 (노량진동)   6922.0  골든볼9 몬스터(지훈식당)
# 1               서울특별시 동작구 상도로38길 3-20 1층 102호 (상도1동)   7032.0        네모푸드 상도점
# 2              서울특별시 동작구 보라매로5길 15 (신대방동전문건설회관 지하1층)      NaN               늘
# 3                         서울특별시 동작구 상도로 122 1층 (상도동)   6959.0            필드키친
# 4                         서울특별시 동작구 노량진로8길 28 (노량진동)   6930.0        백가네해물칼국수
# ..                                               ...      ...             ...
# 331                   서울특별시 동작구 사당로4길 13 (사당동(지상1층))   7030.0            강남식당
# 332                          서울특별시 동작구 성대로5길 2 (상도동)   6960.0         김밥이맛있는집
# 333             서울특별시 동작구 상도로61길 72 지하1층 B102호 (상도동)   7027.0           추억과김밥
# 334  서울특별시 동작구 상도로30길 40 1층 101호 (상도동 두산위브트레지움아파트상가)   6964.0            해피트리
# 335                      서울특별시 동작구 장승배기로 68 1층 (상도동)   6963.0         건강한하루김밥
#
#            최종수정일자 데이터갱신구분           데이터갱신일자    업태구분명      좌표정보(X)  \
# 0    2.020000e+13       U   2021-04-29 2:40       한식  194772.9754
# 1    2.020000e+13       I   2021-02-05 0:23       한식  195365.9867
# 2    2.010000e+13       I  2018-08-31 23:59       한식  193232.0279
# 3    2.020000e+13       I   2021-12-08 0:22       한식  194077.5201
# 4    2.020000e+13       U   2021-12-14 2:40       한식  194347.0685
# ..            ...     ...               ...      ...          ...
# 331  2.020000e+13       I  2018-08-31 23:59  김밥(도시락)  196942.7009
# 332  2.020000e+13       U   2021-12-09 2:40  김밥(도시락)  194027.1309
# 333  2.020000e+13       I  2018-08-31 23:59  김밥(도시락)  196284.0741
# 334  2.020000e+13       U   2020-10-24 2:40  김밥(도시락)  194870.3844
# 335  2.020000e+13       U   2020-10-24 2:40  김밥(도시락)  194597.1781
#
#          좌표정보(Y)    위생업태명
# 0    445623.0802       한식
# 1    444373.1854       한식
# 2    443314.0572       한식
# 3    444347.4355       한식
# 4    445597.5115       한식
# ..           ...      ...
# 331  442766.0717  김밥(도시락)
# 332  444137.2806  김밥(도시락)
# 333  443586.5440  김밥(도시락)
# 334  444631.1127  김밥(도시락)
# 335  444612.8455  김밥(도시락)
#
# [336 rows x 15 columns]

# %%
addr_list = []
for i in range(len(res_table)) :
    data = res_table['지번주소'].str.split(' ')[i][1:3]
    addrs = " ".join(data)
    print(addrs)
    addr_list.append(addrs)
# Out:
# 동작구 노량진동
# 동작구 상도1동
# 동작구 신대방동
# 동작구 상도동
# 동작구 노량진동
# 동작구 흑석동
# 동작구 노량진동
# 동작구 사당동
# 동작구 상도동
# 동작구 상도동
# 동작구 사당동
# 동작구 노량진동
# 동작구 노량진동
# 동작구 노량진동
# 동작구 상도동
# 동작구 상도동
# 동작구 흑석동
# 동작구 사당동
# 동작구 노량진동
# 동작구 노량진동
# 동작구 상도동
# 동작구 대방동
# 동작구 사당동
# 동작구 사당동
# 동작구 흑석동
# 동작구 노량진동
# 동작구 노량진동
# 동작구 신대방동
# 동작구 사당동
# 동작구 사당동
# 동작구 대방동
# 동작구 상도동
# 동작구 대방동
# 동작구 신대방동
# 동작구 흑석동
# 동작구 상도동
# 동작구 상도동
# 동작구 사당동
# 동작구 노량진동
# 동작구 사당동
# 동작구 대방동
# 동작구 흑석동
# 동작구 상도동
# 동작구 대방동
# 동작구 노량진동
# 동작구 사당동
# 동작구 사당동
# 동작구 사당동
# 동작구 상도동
# 동작구 신대방동
# 동작구 흑석동
# 동작구 본동
# 동작구 상도1동
# 동작구 노량진동
# 동작구 노량진동
# 동작구 상도동
# 동작구 상도동
# 동작구 사당동
# 동작구 신대방동
# 동작구 신대방동
# 동작구 대방동
# 동작구 흑석동
# 동작구 노량진동
# 동작구 상도동
# 동작구 흑석동
# 동작구 신대방동
# 동작구 대방동
# 동작구 상도동
# 동작구 노량진동
# 동작구 사당동
# 동작구 노량진동
# 동작구 사당동
# 동작구 상도동
# 동작구 사당동
# 동작구 상도동
# 동작구 사당동
# 동작구 사당동
# 동작구 상도동
# 동작구 노량진동
# 동작구 사당동
# 동작구 노량진동
# 동작구 노량진동
# 동작구 노량진동
# 동작구 상도1동
# 동작구 노량진동
# 동작구 노량진동
# 동작구 노량진동
# 동작구 사당동
# 동작구 노량진동
# 동작구 흑석동
# 동작구 신대방동
# 동작구 상도동
# 동작구 사당동
# 동작구 흑석동
# 동작구 신대방동
# 동작구 사당동
# 동작구 상도동
# 동작구 신대방동
# 동작구 신대방동
# 동작구 노량진동
# 동작구 사당동
# 동작구 신대방동
# 동작구 대방동
# 동작구 상도동
# 동작구 사당동
# 동작구 노량진동
# 동작구 노량진동
# 동작구 상도동
# 동작구 사당동
# 동작구 신대방동
# 동작구 신대방동
# 동작구 흑석동
# 동작구 노량진동
# 동작구 사당동
# 동작구 신대방동
# 동작구 흑석동
# 동작구 노량진동
# 동작구 상도1동
# 동작구 신대방동
# 동작구 신대방동
# 동작구 신대방동
# 동작구 노량진동
# 동작구 신대방동
# 동작구 상도동
# 동작구 사당동
# 동작구 대방동
# 동작구 상도동
# 동작구 대방동
# 동작구 신대방동
# 동작구 흑석동
# 동작구 상도동
# 동작구 노량진동
# 동작구 흑석동
# 동작구 상도1동
# 동작구 흑석동
# 동작구 사당동
# 동작구 상도1동
# 동작구 상도동
# 동작구 사당동
# 동작구 신대방동
# 동작구 대방동
# 동작구 상도동
# 동작구 상도동
# 동작구 상도동
# 동작구 상도동
# 동작구 상도1동
# 동작구 사당동
# 동작구 상도동
# 동작구 상도동
# 동작구 상도동
# 동작구 노량진동
# 동작구 상도동
# 동작구 사당동
# 동작구 상도동
# 동작구 상도동
# 동작구 사당동
# 동작구 사당동
# 동작구 대방동
# 동작구 상도동
# 동작구 대방동
# 동작구 사당동
# 동작구 사당동
# 동작구 상도동
# 동작구 사당동
# 동작구 대방동
# 동작구 상도동
# 동작구 흑석동
# 동작구 상도동
# 동작구 사당동
# 동작구 사당동
# 동작구 사당동
# 동작구 신대방동
# 동작구 사당동
# 동작구 사당동
# 동작구 노량진동
# 동작구 사당동
# 동작구 노량진동
# 동작구 상도1동
# 동작구 상도동
# 동작구 사당동
# 동작구 사당동
# 동작구 흑석동
# 동작구 노량진동
# 동작구 노량진동
# 동작구 흑석동
# 동작구 신대방동
# 동작구 사당동
# 동작구 상도동
# 동작구 사당동
# 동작구 상도동
# 동작구 사당동
# 동작구 사당동
# 동작구 사당동
# 동작구 사당동
# 동작구 사당동
# 동작구 신대방동
# 동작구 노량진동
# 동작구 신대방동
# 동작구 노량진동
# 동작구 상도동
# 동작구 사당동
# 동작구 상도동
# 동작구 대방동
# 동작구 대방동
# 동작구 신대방동
# 동작구 노량진동
# 동작구 상도동
# 동작구 상도동
# 동작구 상도동
# 동작구 상도동
# 동작구 사당동
# 동작구 상도동
# 동작구 사당동
# 동작구 신대방동
# 동작구 상도동
# 동작구 사당동
# 동작구 노량진동
# 동작구 흑석동
# 동작구 신대방동
# 동작구 대방동
# 동작구 노량진동
# 동작구 동작동
# 동작구 흑석동
# 동작구 흑석동
# 동작구 사당동
# 동작구 사당동
# 동작구 상도동
# 동작구 신대방동
# 동작구 노량진동
# 동작구 흑석동
# 동작구 흑석동
# 동작구 사당동
# 동작구 사당동
# 동작구 대방동
# 동작구 본동
# 동작구 신대방동
# 동작구 사당동
# 동작구 노량진동
# 동작구 사당동
# 동작구 상도동
# 동작구 노량진동
# 동작구 흑석동
# 동작구 신대방동
# 동작구 흑석동
# 동작구 사당동
# 동작구 사당동
# 동작구 사당동
# 동작구 노량진동
# 동작구 흑석동
# 동작구 흑석동
# 동작구 신대방동
# 동작구 흑석동
# 동작구 흑석동
# 동작구 노량진동
# 동작구 노량진동
# 동작구 상도1동
# 동작구 상도동
# 동작구 사당동
# 동작구 상도동
# 동작구 흑석동
# 동작구 사당동
# 동작구 노량진동
# 동작구 사당동
# 동작구 상도동
# 동작구 노량진동
# 동작구 상도동
# 동작구 상도동
# 동작구 노량진동
# 동작구 상도동
# 동작구 사당동
# 동작구 상도동
# 동작구 흑석동
# 동작구 사당동
# 동작구 노량진동
# 동작구 사당동
# 동작구 상도동
# 동작구 사당동
# 동작구 상도동
# 동작구 흑석동
# 동작구 사당동
# 동작구 사당동
# 동작구 신대방동
# 동작구 노량진동
# 동작구 상도동
# 동작구 노량진동
# 동작구 사당동
# 동작구 노량진동
# 동작구 사당동
# 동작구 상도동
# 동작구 노량진동
# 동작구 상도동
# 동작구 사당동
# 동작구 대방동
# 동작구 흑석동
# 동작구 상도동
# 동작구 흑석동
# 동작구 사당동
# 동작구 흑석동
# 동작구 흑석동
# 동작구 신대방동
# 동작구 신대방동
# 동작구 사당동
# 동작구 노량진동
# 동작구 신대방동
# 동작구 상도동
# 동작구 흑석동
# 동작구 상도동
# 동작구 대방동
# 동작구 신대방동
# 동작구 대방동
# 동작구 사당동
# 동작구 상도동
# 동작구 상도동
# 동작구 노량진동
# 동작구 흑석동
# 동작구 흑석동
# 동작구 흑석동
# 동작구 상도동
# 동작구 노량진동
# 동작구 노량진동
# 동작구 신대방동
# 동작구 상도동
# 동작구 사당동
# 동작구 노량진동
# 동작구 흑석동
# 동작구 사당동
# 동작구 노량진동
# 동작구 대방동
# 동작구 흑석동
# 동작구 노량진동
# 동작구 상도동
# 동작구 사당동
# 동작구 상도동
# 동작구 상도동
# 동작구 상도동
# 동작구 상도동

# %%
res_table['검색명'] = addr_list +res_table['사업장명']
res_table['검색명']
# Out:
# 0      동작구 노량진동골든볼9 몬스터(지훈식당)
# 1            동작구 상도1동네모푸드 상도점
# 2                   동작구 신대방동늘
# 3                 동작구 상도동필드키친
# 4            동작구 노량진동백가네해물칼국수
#                 ...
# 331               동작구 사당동강남식당
# 332            동작구 상도동김밥이맛있는집
# 333              동작구 상도동추억과김밥
# 334               동작구 상도동해피트리
# 335            동작구 상도동건강한하루김밥
# Name: 검색명, Length: 336, dtype: object

# %%
base_url='https://map.naver.com/v5/?c=14127676.3957465,4523397.9832608,15,0,0,0,dh'

# %%
driver = webdriver.Chrome('./driver/chromedriver')
driver.get(base_url)
time.sleep(2)
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_73740/1372127598.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./driver/chromedriver')

# %%
url_list = []

# %%
for res in tqdm_notebook(res_table['검색명']) :
    try :
        search_xpath = '/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div[1]/div/input'
        element = driver.find_element(By.XPATH, search_xpath)
        time.sleep(0.5)
        element.clear()
        element.send_keys(res)
        element.send_keys("\n")
        time.sleep(3)
        
        url = driver.current_url
        if(url.split('/').__contains__('place')) :
            u = url.split('/')[-1].split('?')[0]
            url_list.append(u)
        else :
            driver.switch_to.frame('searchIframe')
            time.sleep(1)
            
            target_xpath = '/html/body/div[3]/div/div/div[1]/ul/li[1]/div[2]/a[1]/div/div/span[1]'
            config = driver.find_elements(By.XPATH, target_xpath)
            if len(config) == 0 :
                target_xpath = '/html/body/div[3]/div/div/div[1]/ul/li[1]/div[1]/a[1]/div/div/span[1]'
            else :
                target_xpath = '/html/body/div[3]/div/div/div[1]/ul/li[1]/div[2]/a[1]/div/div/span[1]'
                
            element = driver.find_element(By.XPATH, target_xpath)
            element.click()
            time.sleep(2)

            url = driver.current_url
            u = url.split('/')[-1].split('?')[0]
            url_list.append(u)
            time.sleep(1)

            driver.switch_to.default_content()
            time.sleep(1)
                
    except :
        print('error',res)
        url_list.append('-')
        driver.switch_to.default_content()
        time.sleep(1)
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_73740/2534921570.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for res in tqdm_notebook(res_table['검색명']) :
#   0%|          | 0/336 [00:00<?, ?it/s]
# error 동작구 노량진동골든볼9 몬스터(지훈식당)
# error 동작구 상도1동네모푸드 상도점
# error 동작구 상도동필드키친
# error 동작구 흑석동준호가만드는부대찌개
# error 동작구 노량진동우정 감자탕 생삼겹살
# error 동작구 상도동퍼스트푸드
# error 동작구 노량진동우정Ⅲ
# error 동작구 상도동다채샤브 장승배기역점
# error 동작구 상도동팽여사 버섯오리명가
# error 동작구 대방동성찬식당
# error 동작구 신대방동통삼겹구이5900
# error 동작구 상도동겹
# error 동작구 대방동홈인팜스 신대방점
# error 동작구 흑석동양셰프(양Chef)
# error 동작구 사당동골목식당
# error 동작구 상도동이필배의 진짜루명태촌
# error 동작구 상도동(주)라이프키친
# error 동작구 노량진동풍년집
# error 동작구 노량진동배달의 명가
# error 동작구 노량진동포대포소금구이
# error 동작구 상도동부리또집(BURRITO ZIP)
# error 동작구 사당동13번지
# error 동작구 상도1동올바른식당상도점
# error 동작구 신대방동먹거리장터
# error 동작구 상도동골목식당
# error 동작구 대방동제주왕뚜껑생고기
# error 동작구 흑석동개성집
# error 동작구 사당동주말식당
# error 동작구 상도동싹쓰리
# error 동작구 노량진동두마리찜닭 두찜 동작노량진점
# error 동작구 상도동본가피탕김탕
# error 동작구 사당동엄마손 솥단지 삼겹살
# error 동작구 흑석동맛있으면돼지
# error 동작구 사당동푸드100
# error 동작구 상도동예가 숯불갈비
# error 동작구 상도동미가(味佳)
# error 동작구 신대방동브라이트스타 영등포
# error 동작구 동작동하랑F&B
# error 동작구 노량진동불닭발동대문엽기떡볶이 상도노량진점
# error 동작구 노량진동마늘반쪽
# error 동작구 흑석동엉터리생고기&엉터리해장국
# error 동작구 사당동육태기
# error 동작구 노량진동한일정
# error 동작구 사당동엘(L)
# error 동작구 상도동마산아구?동태찜?탕
# error 동작구 노량진동주식회사동양푸드
# error 동작구 노량진동아트카페포차
# error 동작구 사당동에이셉피자 사당방배점(ASAP PIZZA)
# error 동작구 사당동용용선생 이수역점
# error 동작구 노량진동문에프앤비
# error 동작구 흑석동술광장호프치킨
# error 동작구 흑석동박가부대찌개(흑석점)
# error 동작구 대방동미미향24시중화요리
# error 동작구 신대방동차이30(CHAI30)
# error 동작구 사당동구라파중식 팬사이
# error 동작구 상도동삼호핫오리5호점
# error 동작구 흑석동위씨사현스낵(魏記沙縣小吃)
# error 동작구 대방동대성관
# error 동작구 상도동건강한하루김밥

# %%
driver.close()

# %%
res_table['업소URL'] = url_list

# %%
res_table.to_csv('./서울시동작구(업소URL추가).csv', encoding='CP949' )

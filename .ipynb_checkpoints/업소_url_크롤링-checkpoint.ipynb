# %%
# 패키지 임포트
import selenium
from selenium import webdriver
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import time
from tqdm import tqdm_notebook

# %%
res_table = pd.read_csv("./서울시 착한가격음식점(지역추가).csv", encoding='CP949',index_col=0)
res_table
# Out:
#                    업소명  분류코드 분류코드명                           업소 주소  \
# 업소아이디
# 1739          목우촌부추삼겹살     1    한식      서울특별시 관악구 남현1길 68-10 (남현동)
# 4325            청진동해장국     1    한식  서울특별시 관악구 관악로 105 (봉천동) 동산빌딩1층
# 7851             오백냥분식     1    한식         서울특별시 송파구 가락로 112 (석촌동)
# 6764          토방 닭 한마리     1    한식        서울특별시 관악구 신림로22길 5 (신림동)
# 3986   왕세숫대야냉면(행복을파는집)     1    한식         서울특별시 강서구 공항대로 423(등촌동)
# ...                ...   ...   ...                             ...
# 9156             삼겹살데이     1    한식         서울특별시 서대문구 가좌로 29 (연희동)
# 9101              홍능갈비     1    한식        서울특별시 금천구 범안로21길 6 (독산동)
# 9315               보물쌈     1    한식      서울특별시 동작구 상도로 296-2 (상도1동)
# 9279              가정식당     1    한식       서울특별시 강남구 학동로77길 20 (청담동)
# 9069              두부마을     1    한식       서울특별시 강북구 오현로31길 109 (번동)
#
#                 업소 전화번호                                            찾아오시는 길  \
# 업소아이디
# 1739   588-7399          전철 2호선 4호선 사당역에서 5번출구로 나오시면 (구)관악등기소쪽 먹자골목으로 5...
# 4325   875-9882          지하철 2호선 서울대입구역 3번 출구로 나와서 서울대학교 쪽으로 직진 도보10분 관...
# 7851           414-2261  전철노선: 8호선 송파역 4번출구 중동빌딩 버스노서 : 3417.3418.3422....
# 6764   874-6895                                            신성부동산 건물 바로 뒷건물
# 3986       02-2668-3608                     화진코스메틱에서 강서구청4거리쪽으로 조금만 올라오세요~
# ...                 ...                                                ...
# 9156           324-0301                                                NaN
# 9101        02-894-8292                                                NaN
# 9315           814-2151                                                NaN
# 9279        02-514-8009                                                NaN
# 9069           988-8464    4호선 수유역 2번출구에서 하차 후 9또는 11번 마을버스 승차 후 로얄공인중계...
#
#                                                     업소정보  \
# 업소아이디
# 1739   영업시간 : 오전 10시 ~ 오후 11시 30분 좌석수 : 44석 휴무일 : 연중무...
# 4325   영업시간 : 24시간 좌석수 : 80석 휴무일 : 연중무휴  배달 : 불가 예약 :...
# 7851          영업시간:08:00~21:00 휴무일:연중무휴 좌  석:20석 주  차:가능
# 6764   영업시간 : 오전 10시 ~ 오후 10시 좌석수 : 50석 예약 : 가능 카드 : ...
# 3986   영업시간 : 24시간 좌석수 : 30개 휴무일 : 미정 배달 : 불가 카드 : 가능...
# ...                                                  ...
# 9156   영업시간 : 좌석수 : 휴무일 : 배달 : 예약 : 카드 : 주차 : 홈페이지 주소...
# 9101   영업시간 : 12:00~23:00 좌석수 : 휴무일 : 배달 : 불가 예약 : 카드...
# 9315                                       저렴한 가격 깨끗한 위생
# 9279   영업시간 :09:00~21:00 좌석수 : 휴무일 : 배달 :가능 예약 : 카드 :...
# 9069   영업시간 : 9시30분 ~ 21시30분 좌석수 : 80석(16테이블) 휴무일 : 일...
#
#                                                     자랑거리  추천수  기준년월  \
# 업소아이디
# 1739         ▷사당역 먹자골목에 위치 ▷김치찌개된장찌개 2010년부터 가격 동결 ▷친절업소  257  21-2
# 4325      관악구 평균가격(5000원) 보다 10% 저렴 김치 깍두기 등 직접 만들어 신선함.  252  21-2
# 7851                           배  달:불가 예  약:불가 카  드:가능    236  21-2
# 6764   ▷관악구 평균가격보다 10% 저렴 ▷반찬을 여러가지 하지 않고 김치와 깍두기 두가지...  214  21-2
# 3986          많이 판매가 되므로 저렴한 가격유지 그날그날 신선한 재료사용하여 조리합니다.  163  21-2
# ...                                                  ...  ...   ...
# 9156                                                 NaN    0  21-2
# 9101                                                 NaN    0  21-2
# 9315                                       저렴한 가격 깨끗한 위생    0  21-2
# 9279                                                 NaN    0  21-2
# 9069                                                 NaN    0  21-2
#
#                                                    업소 사진         위도  \
# 업소아이디
# 1739   http://tearstop.seoul.go.kr/mulga/photo/201501...  37.475340
# 4325   http://tearstop.seoul.go.kr/mulga/photo/202207...  37.474630
# 7851   http://tearstop.seoul.go.kr/mulga/photo/201207...  37.501272
# 6764   http://tearstop.seoul.go.kr/mulga/photo/202207...  37.471647
# 3986   http://tearstop.seoul.go.kr/mulga/photo/000039...  37.555567
# ...                                                  ...        ...
# 9156            http://tearstop.seoul.go.kr/mulga/photo/  37.577197
# 9101   http://tearstop.seoul.go.kr/mulga/photo/201709...  37.466783
# 9315   http://tearstop.seoul.go.kr/mulga/photo/201909...  37.501177
# 9279   http://tearstop.seoul.go.kr/mulga/photo/201907...  37.519992
# 9069   http://tearstop.seoul.go.kr/mulga/photo/201708...  37.632310
#
#                경도   행정구   행정동
# 업소아이디
# 1739   126.981090   관악구   남현동
# 4325   126.952599   관악구   봉천동
# 7851   127.108509   송파구   석촌동
# 6764   126.935306   관악구   신림동
# 3986   126.854372   강서구   등촌동
# ...           ...   ...   ...
# 9156   126.932276  서대문구   연희동
# 9101   126.896917   금천구   독산동
# 9315   126.948946   동작구  상도1동
# 9279   127.048890   강남구   청담동
# 9069   127.035259   강북구    번동
#
# [733 rows x 15 columns]

# %%
search_res = []
for i in res_table.index :
    addr = []
    addr.append(res_table['행정구'][i])
    addr.append(res_table['행정동'][i])
    addr.append(res_table['업소명'][i])
    str = " ".join(addr)
    search_res.append(str)

# %%
search_res
# Out:
# ['관악구 남현동 목우촌부추삼겹살',
#  '관악구 봉천동 청진동해장국',
#  '송파구 석촌동 오백냥분식',
#  '관악구 신림동 토방 닭 한마리',
#  '강서구 등촌동 왕세숫대야냉면(행복을파는집)',
#  '송파구 석촌동 돌마리유황오리',
#  '송파구 마천동 벧엘 칼국수',
#  '양천구 신월동 보라매25시해장국',
#  '구로구 고척동 해피분식',
#  '광진구 중곡동 금강숯불생고기',
#  '중구 북창동 한우마당',
#  '광진구 자양동 흥부농장',
#  '광진구 구의동 자매식당',
#  '광진구 중곡동 김밥나라',
#  '광진구 중곡동 다비다식당',
#  '동대문구 장안동 궁원 중화요리',
#  '송파구 마천동 제주토방탕수육',
#  '동대문구 이문동 자매식당',
#  '송파구 문정동 한연수짜장',
#  '송파구 잠실동 해주냉면',
#  '송파구 오금동 우돈골',
#  '강서구 가양동 김밥나라',
#  '강서구 등촌동 백미식당',
#  '용산구 남영동 남영해물탕',
#  '송파구 잠실동 장수설렁탕',
#  '강서구 등촌동 부부칼국수',
#  '강동구 성내동 별미 바지락칼국수',
#  '강동구 성내동 뚝배기',
#  '중랑구 묵동 박리김밥',
#  '영등포구 문래동 소소한날',
#  '종로구 효제동 부남돌구이',
#  '노원구 중계동 대림각',
#  '마포구 서교동 봉주르',
#  '종로구 종로4가 일봉',
#  '성북구 동선동 깡통참숯돼지갈비',
#  '송파구 방이동 투가리올림픽',
#  '중구 장충동 산정',
#  '중랑구 망우동 동춘원',
#  '노원구 상계동 다운이',
#  '강북구 수유동 원조막국수',
#  '강서구 화곡동 김밥천국',
#  '구로구 구로동 제주똥돼지촌',
#  '영등포구 영등포동 세림가든',
#  '관악구 신림동 다사랑분식',
#  '관악구 봉천동 수제비손칼국수',
#  '서초구 방배동 미미치킨',
#  '도봉구 창동 미성각',
#  '도봉구 도봉동 도봉산콩나물국밥',
#  '관악구 신림동 신왕짜장',
#  '강동구 천호동 학생회관분식',
#  '서대문구 홍제동 참참치킨',
#  '구로구 고척동 길손한정식',
#  '영등포구 영등포동 제주흑돼지',
#  '용산구 갈월동 감베로니',
#  '서초구 방배동 더구어',
#  '구로구 구로동 대형갈비',
#  '구로구 구로동 명가영양돌솥밥',
#  '중구 신당동 삼성회관',
#  '성동구 성수동 백리향',
#  '성동구 행당동 동해루',
#  '용산구 원효로 무진장',
#  '송파구 마천동 청해루',
#  '구로구 개봉동 설가네부대찌개',
#  '동대문구 용두동 태능숯불갈비',
#  '서대문구 북가좌동 신가네김밥타운',
#  '마포구 신공덕동 라푸스코 마포점',
#  '종로구 창신동 수원성갈비',
#  '서초구 양재동 시골마당',
#  '도봉구 도봉동 시골짚',
#  '관악구 신림동 초밥아저씨',
#  '구로구 고척동 가마솥설렁탕',
#  '서대문구 연희동 연희골굼터',
#  '서대문구 창천동 해주냉면',
#  '송파구 마천동 훼밀리김밥',
#  '송파구 거여동 일심해장국',
#  '관악구 봉천동 만나칼국수',
#  '성동구 하왕십리동 소문난맛함흥냉면',
#  '종로구 창신동 약속다방',
#  '송파구 문정동 홍보성',
#  '구로구 고척동 황궁',
#  '구로구 구로동 중앙한분식',
#  '은평구 녹번동 소백산영주한우',
#  '송파구 마천동 호남식당',
#  '성북구 보문동 대풍손칼국수',
#  '구로구 개봉동 보리밥 솥뚜껑 삼겹살',
#  '노원구 상계동 마들김밥',
#  '중랑구 묵동 와우돈까스',
#  '은평구 갈현동 털보고된이',
#  '서대문구 남가좌동 춘천식당',
#  '강남구 삼성동 삼성돈구이',
#  '서대문구 남가좌동 왕세숫대야냉면',
#  '서대문구 북가좌동 연안식당',
#  '송파구 문정동 함흥냉면(연백냉면)',
#  '금천구 독산동 금천골 오리명가',
#  '양천구 신월동 홍콩반점',
#  '양천구 목동 소문장',
#  '양천구 목동 밥도둑구이전문',
#  '강서구 공항동 시골칼국수',
#  '강북구 미아동 콩아리(전주콩나물국밥)',
#  '양천구 목동 대박집',
#  '강서구 내발산동 메밀이랑 면이랑',
#  '영등포구 영등포동 선유일식',
#  '송파구 방이동 강원도청국장',
#  '광진구 화양동 겨울나그네',
#  '양천구 신월동 북경반점',
#  '양천구 목동 조은식당',
#  '도봉구 방학동 김밥타운',
#  '강남구 대치동 오복냉면',
#  '구로구 구로동 자매분식',
#  '구로구 구로동 우동.짜장',
#  '영등포구 당산동 진국설렁탕',
#  '서대문구 홍제동 미성식당',
#  '양천구 목동 할범탕수육',
#  '관악구 신림동 국수회관',
#  '광진구 구의동 영화속의 김밥이야기',
#  '은평구 대조동 은혜김밥',
#  '성동구 성수동 용짜장',
#  '강남구 논현동 지리산',
#  '성북구 정릉동 정릉갈비',
#  '용산구 갈월동 남영골',
#  '용산구 보광동 한일각',
#  '강북구 수유동 토종집',
#  '강남구 대치동 제일식당',
#  '강남구 논현동 영동원삼겹살',
#  '영등포구 당산동 송백식당',
#  '구로구 오류동 김밥만두집',
#  '강남구 대치동 두꺼비',
#  '서초구 양재동 함흥식당',
#  '구로구 개봉동 해성반점',
#  '강남구 대치동 육판장',
#  '영등포구 양평동 산고을',
#  '노원구 상계동 마시차이나',
#  '구로구 구로동 김밥천국',
#  '도봉구 방학동 일심해장국',
#  '도봉구 도봉동 알뜰정육식당',
#  '동대문구 장안동 오케이식당',
#  '송파구 잠실동 우성숯불갈비',
#  '용산구 한강로2가 화로가',
#  '도봉구 창동 미락칼국수',
#  '강남구 청담동 해남식당',
#  '강남구 개포동 장독묵은지',
#  '서대문구 홍은동 옛고향',
#  '구로구 고척동 해물칼국수',
#  '구로구 오류동 명가분식',
#  '송파구 마천동 마포숯불갈비',
#  '강남구 대치동 미러칼국수',
#  '영등포구 신길동 정원고기마을',
#  '관악구 신림동 다정이모네',
#  '송파구 마천동 유성짬뽕',
#  '강남구 대치동 청실식당',
#  '강남구 역삼동 바우골화로구이',
#  '강서구 가양동 대승식당',
#  '동대문구 제기동 맛고을갈비찜',
#  '구로구 고척동 삼삼치킨',
#  '영등포구 대림동 다솜한식전문',
#  '중구 회현동 조아루',
#  '용산구 남영동 흑돈연가',
#  '강남구 삼성동 향나무집',
#  '강남구 대치동 해피타임',
#  '구로구 개봉동 옛날짜장(중화각)',
#  '용산구 서계동 청운숯불갈비',
#  '송파구 삼전동 정하람남도팥칼국수',
#  '강남구 삼성동 시골청국장',
#  '송파구 삼전동 명품삼겹살점문점',
#  '강남구 대치동 보리수',
#  '송파구 방이동 서울분식',
#  '서대문구 연희동 한분식',
#  '용산구 원효로2가 풍년숯불갈비',
#  '강남구 대치동 대치동영지',
#  '서대문구 북아현동 영화반점',
#  '영등포구 신길동 미각',
#  '마포구 연남동 한성축산식당',
#  '강남구 논현동 청계산갈비살',
#  '서대문구 연희동 황금성',
#  '종로구 연건동 광나루찌개',
#  '광진구 군자동 한아름분식',
#  '구로구 고척동 우리식당',
#  '강남구 수서동 찌개와',
#  '중구 광희동 코너집',
#  '강남구 역삼동 중화요리일품',
#  '구로구 구로동 김밥짱',
#  '관악구 봉천동 만리향',
#  '송파구 송파동 서울중국집',
#  '강남구 개포동 다복콩비지',
#  '강남구 청담동 청숫골보리밥쌈밥',
#  '영등포구 신길동 순미식당',
#  '영등포구 당산동 연경궁',
#  '중랑구 면목동 포도나무',
#  '송파구 거여동 돈구워돈',
#  '영등포구 영등포동 예가원',
#  '강남구 역삼동 고등어식당',
#  '관악구 신림동 다리목',
#  '용산구 용문동 횡성한우목장',
#  '영등포구 여의도동 지리산',
#  '도봉구 방학동 돈애우',
#  '서대문구 대현동 진사골왕갈비',
#  '강남구 논현동 항아리 숯불갈비',
#  '구로구 구로동 미진분식',
#  '강북구 수유동 지우정',
#  '송파구 오금동 본향',
#  '관악구 봉천동 중앙삼겹시대',
#  '성동구 금호동 씨씨존치킨',
#  '용산구 갈월동 모리모리',
#  '양천구 신월동 돈스우스',
#  '종로구 적선동 또순이네',
#  '성북구 상월곡동 미락',
#  '광진구 자양동 공새미김밥',
#  '관악구 남현동 제주토종흑돼지',
#  '강북구 미아동 만미정 식당',
#  '중구 다동 다동분식',
#  '성북구 정릉동 서울숯불갈비',
#  '중랑구 묵동 할매김밥',
#  '구로구 개봉동 한우식당',
#  '강남구 대치동 왕가네왕만두',
#  '강동구 길동 모아분식',
#  '강서구 방화동 송주불냉면',
#  '강남구 논현동 바보네집',
#  '송파구 삼전동 신성김밥',
#  '중랑구 면목동 화성각',
#  '도봉구 도봉동 난짜장 넌짬뽕',
#  '구로구 고척동 왕짜장',
#  '중구 회현동 소달구지',
#  '도봉구 방학동 털보식당',
#  '강남구 논현동 청송숯불화로구이',
#  '강남구 대치동 한보식당',
#  '송파구 마천동 국일관',
#  '성북구 정릉동 보성각',
#  '종로구 연건동 퓨전 한마당',
#  '강남구 역삼동 수미정',
#  '동대문구 제기동 금복식당',
#  '구로구 구로동 일억조분식',
#  '송파구 석촌동 소백산',
#  '구로구 개봉동 닷컴분식',
#  '종로구 낙원동 먹고갈래지고갈래',
#  '강남구 개포동 우리생고기',
#  '용산구 효창동 산골녹차냉면',
#  '구로구 개봉동 화승원',
#  '강남구 대치동 사천옥',
#  '관악구 봉천동 송림정',
#  '관악구 봉천동 유창숯불갈비',
#  '구로구 개봉동 개봉분식',
#  '종로구 내자동 콩나물국밥',
#  '구로구 개봉동 완산정',
#  '중구 저동 영자씨우동김밥',
#  '구로구 구로동 칭니',
#  '송파구 방이동 방이맛집',
#  '강남구 신사동 양철집',
#  '종로구 동숭동 삼삼뚝배기',
#  '중랑구 중화동 분식나라',
#  '마포구 도화동 솔잎식당',
#  '도봉구 방학동 신짜장',
#  '성북구 동소문동 홍두깨손칼국수',
#  '노원구 상계동 진식당',
#  '종로구 종로5가 왕관커피숍',
#  '강남구 대치동 여신김밥',
#  '용산구 이태원동 황소마을',
#  '강남구 역삼동 윤화돈까스기사식당',
#  '성북구 삼선동 두메산골',
#  '강남구 개포동 노숙자아구샤브샤브',
#  '광진구 능동 홍천화로숯불갈비',
#  '광진구 구의동 옥문',
#  '광진구 구의동 성원식당',
#  '강남구 개포동 누이야식당',
#  '영등포구 양평동 서울초밥',
#  '강남구 역삼동 돈까스리',
#  '관악구 봉천동 원조정가네매운갈비찜',
#  '광진구 중곡동 이삭홍두깨칼국수',
#  '마포구 망원동 고향집',
#  '강동구 성내동 명가손칼국수',
#  '송파구 방이동 춘향고을',
#  '영등포구 영등포동 낭주골',
#  '영등포구 대림동 유미식당',
#  '서대문구 홍은동 풍년갈비',
#  '마포구 망원동 새마을',
#  '광진구 군자동 세종하늘마루',
#  '은평구 신사동 꾸워',
#  '강남구 개포동 동대문곱창전문',
#  '광진구 자양동 기덕이네생고기집',
#  '송파구 방이동 메운불닭',
#  '서초구 서초동 미각',
#  '영등포구 영등포동 짜우리아',
#  '중랑구 망우동 얼레리꼴레리',
#  '마포구 공덕동 효성마루(효성식당)',
#  '중랑구 망우동 웰빙 콩나물',
#  '노원구 상계동 착한메밀',
#  '성북구 삼선동 밀밭 손 칼국수',
#  '강남구 삼성동 전주비빔밥',
#  '강남구 개포동 바지락칼국수',
#  '서초구 서초동 탐라도야지',
#  '강남구 일원동 한우정육점식당',
#  '관악구 봉천동 김밥분식',
#  '송파구 마천동 꾸어구어',
#  '강남구 역삼동 이모네분식',
#  '금천구 시흥동 전주콩나물국밥',
#  '중랑구 면목동 황금돼지갈비',
#  '영등포구 양평동 삼미식당',
#  '성북구 하월곡동 허브족발',
#  '관악구 봉천동 어메칼국수',
#  '성북구 삼선동 최진사댁두부마을',
#  '강남구 개포동 처갓집',
#  '강남구 역삼동 커피알',
#  '양천구 목동 명동손칼국수',
#  '강남구 역삼동 숙아채콩나물국밥역삼1호점',
#  '구로구 구로동 용갈비',
#  '금천구 시흥동 서담',
#  '송파구 풍납동 장수촌',
#  '관악구 신림동 고시칼국수',
#  '중랑구 상봉동 신 쿡(cook)',
#  '동대문구 이문동 아마자께',
#  '중랑구 망우동 정가네 홍두깨 손칼국수',
#  '동대문구 제기동 안동장',
#  '강북구 미아동 박가네생고기전문점',
#  '송파구 잠실동 조은김밥',
#  '용산구 한강로2가 옛날막고기집',
#  '용산구 한남동 진부령황태해장국',
#  '송파구 거여동 모퉁이식당',
#  '강북구 우이동 백곰집',
#  '강남구 삼성동 트윈쿡',
#  '중랑구 망우동 광양불고기',
#  '동대문구 휘경동 놀부만두',
#  '강서구 화곡동 옛날칼국수',
#  '중랑구 면목동 고향김밥',
#  '강서구 화곡동 함흥냉면 명가',
#  '광진구 화양동 북경',
#  '송파구 석촌동 옛날맛짜장',
#  '강남구 삼성동 가득드림',
#  '금천구 독산동 고기마을호수',
#  '강남구 개포동 수타손짜장',
#  '중랑구 면목동 명동분식',
#  '강남구 대치동 강남김밥',
#  '서대문구 북가좌동 한솔 민물장어',
#  '송파구 잠실동 김자순수제돈까스',
#  '송파구 풍납동 마포숯불갈비',
#  '광진구 능동 소야지',
#  '서대문구 창천동 콩각시',
#  '송파구 마천동 착한깡통',
#  '강동구 길동 토속칼국수',
#  '금천구 독산동 동남숯불생구이',
#  '금천구 시흥동 듬배골',
#  '강남구 개포동 숙아채 콩나물국밥(개포)',
#  '관악구 신림동 착한우동짜장',
#  '구로구 구로동 형제갈비',
#  '금천구 독산동 대호식당',
#  '서대문구 북가좌동 엄마손밥상',
#  '동작구 신대방동 성상등갈비',
#  '동작구 노량진동 궁중순대보쌈',
#  '강동구 성내동 명동찌개마을',
#  '동작구 사당동 내고향 나주곰탕',
#  '동작구 사당동 은혜식당',
#  '동작구 상도동 화풍정',
#  '동작구 신대방동 우리 콩사랑',
#  '강남구 개포동 나드리식당',
#  '동작구 신대방동 이고시다',
#  '서대문구 홍은동 엉터리돼지갈비',
#  '서대문구 북가좌동 다미돈까스',
#  '서대문구 창천동 조정현갈비탕',
#  '강남구 도곡동 도곡한우소머리국밥',
#  '강남구 도곡동 선우동가게',
#  '서대문구 남가좌동 이삭칼국수',
#  '관악구 신림동 착한생칼국수',
#  '노원구 중계동 불암골 맛있는 집',
#  '구로구 구로동 싸리골',
#  '동작구 상도1동 향기가득한 인생감자탕',
#  '강남구 대치동 부부식당',
#  '강남구 역삼동 예향',
#  '서대문구 홍은동 만리장성',
#  '강남구 수서동 지리산 생고기',
#  '강남구 대치동 더스푼',
#  '강남구 역삼동 신의주찹쌀순대감자탕',
#  '관악구 신림동 보글보글 지글지글',
#  '강남구 논현동 돈먹고돈내고',
#  '강남구 신사동 알리파스타',
#  '강남구 개포동 노다지',
#  '동작구 대방동 남원집',
#  '중구 오장동 남도전통순대명가',
#  '서대문구 홍제동 어가네',
#  '서대문구 홍제동 생삼이네',
#  '강남구 개포동 대청김밥',
#  '강남구 대치동 예자네밥상',
#  '중구 충무로2가 카페 베아띠',
#  '서대문구 홍은동 곰닭',
#  '강서구 화곡동 우리식당',
#  '금천구 가산동 다  담',
#  '강남구 대치동 요기루',
#  '금천구 시흥동 금천식당',
#  '강남구 논현동 남도맛집',
#  '강남구 율현동 오감만족',
#  '강남구 역삼동 멀티분식',
#  '도봉구 창동 의정부 부대찌개',
#  '서대문구 홍제동 한잎',
#  '금천구 시흥동 신가네참숯민물장어',
#  '강남구 도곡동 남원종가집추어탕',
#  '강남구 신사동 가로수길칼국수',
#  '영등포구 신길동 옛날짜장',
#  '광진구 중곡동 돈필',
#  '광진구 군자동 생생칼국수',
#  '강남구 역삼동 국민우동집',
#  '금천구 독산동 얼큰순대국',
#  '동대문구 청량리동 속초맛집',
#  '송파구 가락동 미라클센터',
#  '송파구 가락동 미라클센터',
#  '송파구 가락동 미라클센터',
#  '도봉구 방학동 어머니찌개',
#  '관악구 봉천동 즉석우동짜장',
#  '중구 서소문동 씨티스퀘어',
#  '동작구 상도동 아이리스 분식',
#  '노원구 월계동 태성순대국',
#  '마포구 연남동 풍년갈비',
#  '노원구 월계동 향원',
#  '관악구 봉천동 우리가참순대',
#  '동작구 사당동 용주골 생고기',
#  '금천구 시흥동 은행나무갈매기',
#  '동작구 흑석동 맛구이촌',
#  '동작구 사당동 사당골',
#  '서대문구 연희동 비락',
#  '서대문구 홍제동 가원',
#  '도봉구 방학동 명동분식',
#  '강남구 신사동 누이네',
#  '강남구 역삼동 밥리버거 앤 치킨호프',
#  '강남구 역삼동 대풍참숯갈비',
#  '동작구 신대방동 돈까스 참 잘하는 집',
#  '강남구 삼성동 밀가칼국수',
#  '강남구 도곡동 만금성',
#  '마포구 상암동 커피농부와정원',
#  '동작구 상도동 대가설렁탕',
#  '동작구 신대방동 궁중참순대',
#  '서대문구 홍제동 더케익부티크',
#  '강남구 수서동 손칼국수&손만두',
#  '구로구 구로동 삼거리식당',
#  '동작구 사당동 진미 순대국 감자탕',
#  '관악구 봉천동 투가리(서울밥집 낙성대역점)',
#  '광진구 능동 능라도분식',
#  '종로구 수송동 플러스카페',
#  '중구 신당동 복지로분식',
#  '동작구 노량진동 노들나루 밥상',
#  '영등포구 영등포동 옥문',
#  '금천구 가산동 꼼이네',
#  '서대문구 북가좌동 커피디인',
#  '마포구 신공덕동 차이나는만두',
#  '동작구 사당동 남원추어탕',
#  '동작구 상도동 낙지랑 갈비랑',
#  '광진구 자양동 보현식당',
#  '동작구 흑석동 사과나무',
#  '금천구 시흥동 육합춘짜장짬뽕전문',
#  '광진구 중곡동 면곡당',
#  '관악구 봉천동 시민식당',
#  '강남구 대치동 순대국밥',
#  '관악구 신림동 버거랩',
#  '관악구 신림동 서울밥집',
#  '금천구 가산동 자연화로구이',
#  '강남구 도곡동 365일기분좋은날잔치날',
#  '마포구 망원동 참맛 닭곰탕',
#  '강남구 역삼동 강남제비',
#  '도봉구 창동 남원추어탕',
#  '서대문구 홍은동 홍은나루터',
#  '노원구 월계동 다이천 마떡',
#  '마포구 서교동 웰빙뚝배기',
#  '강남구 신사동 양구식당',
#  '마포구 연남동 연희동 할머니네',
#  '강남구 개포동 소담',
#  '서대문구 홍제동 1번출구커피',
#  '강남구 역삼동 이모네손칼국수',
#  '금천구 시흥동 산들바다 생고기',
#  '금천구 가산동 가산순대국',
#  '강남구 일원동 누렁국수',
#  '강남구 신사동 하하',
#  '강남구 일원동 한벽루 전주콩나물국밥',
#  '동작구 노량진동 와가마마',
#  '서대문구 북가좌동 중화요리 신세계로반점',
#  '동작구 노량진동 우정식당',
#  '동작구 상도1동 북경',
#  '동작구 상도동 코코스 중앙식당',
#  '마포구 연남동 미소국수',
#  '광진구 군자동 세종원',
#  '마포구 도화동 경성커피컴퍼니',
#  '강남구 개포동 미도한우마을',
#  '동작구 노량진동 금옥이네',
#  '동작구 사당동 남원추어탕아구찜',
#  '동작구 사당동 풍미원',
#  '중랑구 신내동 세븐돈가스',
#  '강남구 도곡동 신토불이 정육식당',
#  '강남구 수서동 팔팔한상',
#  '관악구 신림동 추억의 통치킨',
#  '광진구 중곡동 마니아우동',
#  '동작구 사당동 배꼽시계',
#  '종로구 효제동 진차돌',
#  '관악구 신림동 추억순대국전문점',
#  '동작구 흑석동 유정쌈밥',
#  '동작구 흑석동 단비분식',
#  '동작구 노량진동 다독이네 숯불갈비',
#  '구로구 구로동 현미식당',
#  '동작구 사당동 생오리 회전 숯불구이 왕갈비탕',
#  '동작구 사당동 돌쇠와 석쇠',
#  '동작구 노량진동 엄마손김밥',
#  '동작구 노량진동 스카이 피자',
#  '성북구 삼선동 오늘김밥',
#  '강남구 역삼동 역삼정',
#  '강남구 역삼동 고향한식부페',
#  '강서구 등촌동 문가네식당',
#  '강남구 개포동 서희네',
#  '종로구 창신동 만족숯불갈비',
#  '마포구 망원동 동일루',
#  '강남구 역삼동 엄마손김밥',
#  '구로구 구로동 국수뜨락',
#  '강남구 역삼동 대영식당',
#  '강남구 논현동 비바비보 앤 호프',
#  '강남구 역삼동 행복한밥상',
#  '관악구 봉천동 이모네식당',
#  '동작구 신대방동 통삼겹구이 5900',
#  '강남구 역삼동 임가네민속집',
#  '동작구 대방동 전라도 시래기국밥',
#  '구로구 구로동 무릉도원',
#  '강남구 도곡동 황가솥뚜껑삼겹살',
#  '강남구 역삼동 육천중국요리',
#  '강남구 개포동 맛찬',
#  '강남구 일원동 서평기사식당',
#  '동작구 신대방동 삼호정',
#  '동대문구 장안동 제일정육식당',
#  '서대문구 영천동 떡마을카페',
#  '서대문구 창천동 대명꼬기',
#  '서대문구 북가좌동 소문난냉면',
#  '서대문구 홍제동 칼집삼겹살',
#  '서대문구 홍제동 홍제동잔치집',
#  '강남구 도곡동 원할매이모네닭한마리',
#  '중구 회현동 속초집',
#  '강남구 일원동 맛있는돈까스',
#  '강남구 역삼동 사랑의 도시락',
#  '서대문구 북가좌동 화순식당',
#  '중구 필동 대청마루',
#  '광진구 자양동 보광식당',
#  '광진구 자양동 종로한정식',
#  '중구 남산동 우리집 맛자랑',
#  '중구 광희동 광희식당',
#  '금천구 독산동 진미식당',
#  '중구 북창동 돈우가',
#  '서대문구 북가좌동 청와면옥함흥냉면',
#  '마포구 연남동 오군 수제 고로케',
#  '강남구 개포동 양평해장국',
#  '중구 신당동 형제정육식당',
#  '강남구 도곡동 석화촌',
#  '강남구 수서동 오가네밥상',
#  '노원구 상계동 짬뽕늬우스',
#  '노원구 공릉동 형제해장국',
#  '마포구 망원동 망원시장홍두깨손칼국수',
#  '서대문구 창천동 나주식당',
#  '중구 신당동 흑돈연가',
#  '서대문구 북가좌동 낙원식당',
#  '강남구 수서동 행복한 잔치국수',
#  '서대문구 홍제동 축산정육식당',
#  '금천구 가산동 박리분식',
#  '광진구 자양동 자매생고기',
#  '금천구 가산동 고기굽는마을',
#  '금천구 시흥동 풍천장어',
#  '금천구 독산동 다래성',
#  '금천구 시흥동 장수갈비',
#  '금천구 독산동 조여사네집',
#  '강남구 대치동 행운식당',
#  '강남구 개포동 김밥여행',
#  '강남구 신사동 월드맛집',
#  '마포구 동교동 웨스턴후라이드라이스',
#  '도봉구 방학동 홍두깨손칼국수',
#  '중구 신당동 일일구(119)',
#  '강남구 일원동 시골애 청국장',
#  '강남구 역삼동 만두랑',
#  '강서구 등촌동 중화요리 명가',
#  '금천구 독산동 진미한분식',
#  '금천구 가산동 참치킹',
#  '강남구 수서동 풍경한식',
#  '금천구 독산동 만세한식부페본점',
#  '중구 회현동 그냥밥집',
#  '중구 중림동 정원설렁탕(민속의집)',
#  '중구 북창동 남도한식-정든님고운님',
#  '금천구 시흥동 홍두깨손칼국수',
#  '관악구 신림동 포천이동갈비촌',
#  '중구 황학동 장수보리밥',
#  '강남구 역삼동 명동만두',
#  '강남구 수서동 만아정육점식당',
#  '중구 황학동 장충동한방왕족발',
#  '서대문구 북가좌동 소돈',
#  '중구 회현동 유가',
#  '강남구 대치동 고기마을',
#  '강북구 번동 수유시골집',
#  '관악구 봉천동 서울밥집 봉천점',
#  '금천구 가산동 맛순이순대국감자탕',
#  '강남구 역삼동 영동우동',
#  '관악구 봉천동 옥천골',
#  '강동구 명일동 다인',
#  '성동구 하왕십리동 송하정',
#  '강남구 개포동 강남본돼지갈비',
#  '광진구 중곡동 중국관',
#  '중구 회현동 진달래 시래기',
#  '서대문구 남가좌동 송림기사식당',
#  '관악구 신림동 신림국수',
#  '마포구 망원동 빈대떡마을',
#  '마포구 망원동 망원동수창골',
#  '마포구 신수동 구대회커피',
#  '강동구 성내동 서울진우동덮밥',
#  '노원구 공릉동 북한강민물고기매운탕',
#  '강남구 역삼동 황태사랑',
#  '관악구 봉천동 바른꽈배기',
#  '관악구 신림동 엄마가',
#  '서대문구 창천동 명물갈비',
#  '금천구 시흥동 정가네촌 감자탕',
#  '금천구 가산동 포스트푸드',
#  '도봉구 창동 돼지물고기',
#  '서대문구 연희동 본솔커피',
#  '서대문구 홍제동 밥 보다 국시',
#  '노원구 월계동 돈장군',
#  '노원구 월계동 여자만아구찜',
#  '노원구 상계동 뚱뚱이 밥상',
#  '동작구 상도동 이가떡방',
#  '동작구 상도동 동가보쌈',
#  '동작구 신대방동 신대방대박찹쌀꽈배기',
#  '동작구 대방동 남원추어탕',
#  '금천구 가산동 푸드플러스',
#  '금천구 시흥동 국수집',
#  '마포구 성산동 선자네',
#  '강남구 역삼동 대풍참숯갈비',
#  '강서구 화곡동 먹깨비 김밥',
#  '동작구 사당동 황제소고기국밥',
#  '동작구 상도동 정선메밀고을',
#  '동작구 노량진동 모꼬지',
#  '동작구 사당동 달길포차',
#  '동작구 본동 고향갈비',
#  '동작구 사당동 마포곱창',
#  '동작구 흑석동 남매이야기',
#  '동작구 흑석동 준호가만드는부대찌개',
#  '동작구 대방동 호순네집',
#  '동작구 대방동 실비촌',
#  '동작구 대방동 삼락',
#  '동작구 신대방동 황금오리',
#  '마포구 성산동 해피하우스소정',
#  '도봉구 쌍문동 카페매일이기념일',
#  '마포구 성산동 냠냠분식',
#  '관악구 신림동 어느멋진날',
#  '도봉구 도봉동 홍방원',
#  '관악구 신림동 고시칼국수',
#  '도봉구 쌍문동 착한부대찌개',
#  '광진구 군자동 채움',
#  '은평구 응암동 커피홀릭',
#  '광진구 군자동 옥돌바베큐',
#  '광진구 구의동 지니카페',
#  '도봉구 방학동 짱구네분식',
#  '도봉구 방학동 호돈구이',
#  '도봉구 방학동 짜장마을',
#  '도봉구 창동 엄마랑꿀꽈배기',
#  '도봉구 창동 멸치국수',
#  '도봉구 방학동 김가네국수집',
#  '도봉구 방학동 아!짜장',
#  '도봉구 창동 화원',
#  '도봉구 도봉동 홍두깨손칼국수',
#  '도봉구 도봉동 온누리식당',
#  '도봉구 도봉동 보배네능이백숙',
#  '도봉구 방학동 브레쉬에비뉴',
#  '도봉구 방학동 세움카페',
#  '도봉구 창동 박리김밥',
#  '도봉구 방학동 카페커민',
#  '성동구 하왕십리동 전주식당',
#  '도봉구 쌍문동 우이목장',
#  '관악구 신림동 카페해밀',
#  '도봉구 쌍문동 행촌',
#  '구로구 가리봉동 삼동숯불갈비',
#  '구로구 가리봉동 우리집',
#  '성동구 금호동 금호동바다장어초이408',
#  '성동구 금호동 고향냉면',
#  '은평구 갈현동 행복밥상',
#  '은평구 갈현동 양구손두부',
#  '은평구 역촌동 은평닭곰탕',
#  '강남구 신사동 알리파스타',
#  '광진구 자양동 엄마손집밥',
#  '중랑구 망우동 다담2900',
#  '관악구 신림동 수자타착한식당',
#  '중랑구 면목동 동해루',
#  '중랑구 면목동 짜장나루',
#  '중랑구 중화동 커피앤바복길이',
#  '관악구 신림동 굿띵커피',
#  '동작구 대방동 신온누리에돈까스',
#  '양천구 신월동 명가 홍삼을담다',
#  '구로구 고척동 포에리얼 떡볶이',
#  '구로구 구로동 고창국수',
#  '광진구 자양동 자양다방',
#  '강서구 마곡동 머리못하는 집',
#  '동작구 상도1동 옛날칼국수',
#  '동작구 흑석동 준호네 돈가스',
#  '동작구 대방동 제주왕뚜껑생고기',
#  '강남구 역삼동 시골밥상',
#  '동작구 상도동 동해해물탕',
#  '동작구 대방동 준우식당',
#  '동작구 신대방동 풀향기칼국수',
#  '동작구 흑석동 계단집',
#  '동작구 사당동 산천칡냉면',
#  '동작구 흑석동 황토정',
#  '동작구 노량진동 정가네밥상',
#  '구로구 고척동 꿀꿀이생고기맛집',
#  '구로구 구로동 윤경이네',
#  '구로구 구로동 명태본가',
#  '마포구 연남동 사루카메',
#  '용산구 원효로1가 일공오삼겹살',
#  '마포구 도화동 전주집',
#  '관악구 신림동 마마떼',
#  '용산구 한강로2가 용산풍천숯불민물장어',
#  '용산구 서빙고동 원돈까스우동',
#  '성동구 금호동 원조칼국수',
#  '동작구 노량진동 큰손갈비',
#  '동작구 상도1동 명동국수',
#  '동작구 상도동 상도칼국수',
#  '동작구 신대방동 섬마을일식',
#  '강동구 성내동 미소분식',
#  '중랑구 망우동 오늘우리집비어',
#  '관악구 신림동 가름커피',
#  '강남구 역삼동 삼탱이시래기밥',
#  '용산구 용산동 면마루',
#  '용산구 원효로2가 용산장어마을',
#  '용산구 동빙고동 영광정육식당',
#  '관악구 신림동 풍년집본가',
#  '관악구 신림동 네이밍카페커피GO!#1',
#  '관악구 봉천동 맛조탕',
#  '은평구 응암동 시장냉면',
#  '은평구 응암동 OK스시',
#  '은평구 응암동 멸치국수',
#  '은평구 불광동 우경촌',
#  '은평구 갈현동 솥뚜껑',
#  '은평구 역촌동 역촌동 멸치국수',
#  '동작구 대방동 태원',
#  '서대문구 홍은동 엉터리돼지갈비',
#  '동작구 흑석동 일이삼식당',
#  '동작구 상도동 만두의정석',
#  '마포구 창전동 옛날무쇠가마솥',
#  '서대문구 연희동 삼겹살데이',
#  '금천구 독산동 홍능갈비',
#  '동작구 상도1동 보물쌈',
#  '강남구 청담동 가정식당',
#  '강북구 번동 두부마을']

# %%
res_table['검색명'] = search_res

# %%
base_url='https://map.naver.com/v5/?c=14127676.3957465,4523397.9832608,15,0,0,0,dh'

# %%
driver = webdriver.Chrome('./driver/chromedriver')
driver.get(base_url)
time.sleep(2)
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_24888/1372127598.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./driver/chromedriver')

# %%
url_list = []

# %%
for res in tqdm_notebook(res_table['검색명']) :
    try :
        search_xpath = '/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div[1]/div/input'
        element = driver.find_element(By.XPATH, search_xpath)
        time.sleep(0.5)
        element.clear()
        element.send_keys(res)
        element.send_keys("\n")
        time.sleep(3)
        
        url = driver.current_url
        if(url.split('/').__contains__('place')) :
            u = url.split('/')[-1].split('?')[0]
            url_list.append(u)
        else :
            driver.switch_to.frame('searchIframe')
            time.sleep(1)
            
            target_xpath = '/html/body/div[3]/div/div/div[1]/ul/li[1]/div[2]/a[1]/div/div/span[1]'
            config = driver.find_elements(By.XPATH, target_xpath)
            if len(config) == 0 :
                target_xpath = '/html/body/div[3]/div/div/div[1]/ul/li[1]/div[1]/a[1]/div/div/span[1]'
            else :
                target_xpath = '/html/body/div[3]/div/div/div[1]/ul/li[1]/div[2]/a[1]/div/div/span[1]'
                
            element = driver.find_element(By.XPATH, target_xpath)
            element.click()
            time.sleep(2)

            url = driver.current_url
            u = url.split('/')[-1].split('?')[0]
            url_list.append(u)
            time.sleep(1)

            driver.switch_to.default_content()
            time.sleep(1)
                
    except :
        print('error',res)
        url_list.append('-')
        driver.switch_to.default_content()
        time.sleep(1)

# %%
driver.close()

# %%
res_table['업소URL'] = url_list

# %%
res_table.to_csv('./datas/서울시 착한가격음식점(업소URL추가).csv', encoding='CP949' )
